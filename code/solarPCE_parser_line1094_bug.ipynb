# %% [markdown]
# This following code highlights a bug in the original solarPCE_parser.py (lines 1093 and 1094 of origin/main of 2021-09-15, hash a47054ae558a25b07a070c54c3aba259d7db6d8d)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Mix-up of 'LUMOOffset', 'HOMOOffset', and 'D-HOMO & A-LUMO offset'

# %%
DFT_acceptors = pd.read_csv('../data_csv/DFT_acceptor_data.csv')
acceptors = DFT_acceptors['Acceptor'].tolist()

# %%
DFT_donors = pd.read_csv('../data_csv/DFT_donor_data.csv')
donors = DFT_donors['Donor'].tolist()

# %%
DFT_offsets = pd.read_csv('../data_csv/DFT_offset_data.csv')
offset_pair = DFT_offsets['Acc-Don Pair'].tolist()
lumo_offset = DFT_offsets['LUMO offset'].tolist()
homo_offset = DFT_offsets['HOMO offset'].tolist()
donHOMO_accLUMO_offset = DFT_offsets['D-HOMO & A-LUMO offset'].tolist()

# %%
bad = 0; good = 0;
for i in range(len(acceptors)):
    for x in range(len(donors)): 
        donors[x] = donors[x].split('_',1)[0]
        cands = [] # New variable to keep track of collisions
        p_true = None
        for p in range(len(offset_pair)):
            # The following two lines are problematic:
            if str(acceptors[i]) in str(offset_pair[p]):
                if str(donors[x]) in str(offset_pair[p]):
                    cands.append(p)
            # This is the correct match criterion:
            if offset_pair[p] == f"{acceptors[i]}/{donors[x]}":
                p_true = p
        if len(cands) != 1:
            p_picked = cands[0] # In the solarPCE_parser, the first one is picked (break after first match)
            if offset_pair[p_picked] != f"{acceptors[i]}/{donors[x]}":
                print(f"For acc={acceptors[i]}, don={donors[x]}, the pairs entry {offset_pair[p_picked]} was wrongly picked!")
                print(f"  Got 'LUMOOffset' = {lumo_offset[p_picked]:g} instead of {lumo_offset[p_true]:g}")
                print(f"  Got 'HOMOOffset' = {homo_offset[p_picked]:g} instead of {homo_offset[p_true]:g}")
                print(f"  Got 'D-HOMO & A-LUMO offset' = {donHOMO_accLUMO_offset[p_picked]:g} instead of {donHOMO_accLUMO_offset[p_true]:g}")
                bad += 1
            else:
                print(f"Lucky, but just because {offset_pair[p_picked]} appeared before {offset_pair[cands[-1]]}.")
                good += 1
        else:
            good += 1
print(f"{bad} out of {good+bad} were bad!")
# Out:
# For acc=BTA53, don=PBDB-T, the pairs entry BTA53/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.698979 instead of 0.565571
#   Got 'HOMOOffset' = 0.103512 instead of 0.279107
#   Got 'D-HOMO & A-LUMO offset' = 1.6618 instead of 1.4862
# For acc=i-cc23, don=PBDB-T, the pairs entry i-cc23/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.859654 instead of 0.726246
#   Got 'HOMOOffset' = 0.0214154 instead of 0.19701
#   Got 'D-HOMO & A-LUMO offset' = 1.50112 instead of 1.32553
# For acc=Y14, don=PBDB-T, the pairs entry Y14/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.813538 instead of 0.68013
#   Got 'HOMOOffset' = 0.285964 instead of 0.46156
#   Got 'D-HOMO & A-LUMO offset' = 1.54724 instead of 1.37165
# For acc=IPTBO-4Cl, don=PBDB-T, the pairs entry IPTBO-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.00222 instead of 0.86881
#   Got 'HOMOOffset' = 0.32455 instead of 0.500145
#   Got 'D-HOMO & A-LUMO offset' = 1.35856 instead of 1.18297
# For acc=H2, don=PBDB-T, the pairs entry H2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.964034 instead of 0.830625
#   Got 'HOMOOffset' = 0.373476 instead of 0.549071
#   Got 'D-HOMO & A-LUMO offset' = 1.39675 instead of 1.22115
# For acc=NITV, don=PBDB-T, the pairs entry NITV/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.656694 instead of 0.523286
#   Got 'HOMOOffset' = 0.387762 instead of 0.563357
#   Got 'D-HOMO & A-LUMO offset' = 1.70408 instead of 1.52849
# For acc=IDF-IC, don=PBDB-T, the pairs entry IDF-IC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.857778 instead of 0.724369
#   Got 'HOMOOffset' = 0.476145 instead of 0.65174
#   Got 'D-HOMO & A-LUMO offset' = 1.503 instead of 1.32741
# For acc=Y6, don=PBDB-T, the pairs entry Y6/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.998348 instead of 0.86494
#   Got 'HOMOOffset' = 0.499737 instead of 0.675332
#   Got 'D-HOMO & A-LUMO offset' = 1.36243 instead of 1.18684
# For acc=M34, don=PBDB-T, the pairs entry M34/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.998646 instead of 0.865238
#   Got 'HOMOOffset' = 0.390483 instead of 0.566078
#   Got 'D-HOMO & A-LUMO offset' = 1.36213 instead of 1.18654
# Lucky, but just because SeTIC/PTB7-Th appeared before SeTIC4Cl/PTB7-Th.
# Lucky, but just because SeTIC/PBDB-TF appeared before SeTIC4Cl/PBDB-TF.
# Lucky, but just because SeTIC/PDCBT-Cl appeared before SeTIC4Cl/PDCBT-Cl.
# Lucky, but just because SeTIC/P3HT appeared before SeTIC4Cl/P3HT.
# For acc=SeTIC, don=PBDB-T, the pairs entry SeTIC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.892033 instead of 0.758624
#   Got 'HOMOOffset' = 0.281502 instead of 0.457097
#   Got 'D-HOMO & A-LUMO offset' = 1.46875 instead of 1.29315
# Lucky, but just because SeTIC/PBDB-T-2Cl appeared before SeTIC4Cl/PBDB-T-2Cl.
# For acc=N3, don=PBDB-T, the pairs entry N3/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.03259 instead of 0.899185
#   Got 'HOMOOffset' = 0.510649 instead of 0.686244
#   Got 'D-HOMO & A-LUMO offset' = 1.32819 instead of 1.15259
# For acc=CPDT-4Cl, don=PBDB-T, the pairs entry CPDT-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.06216 instead of 0.928751
#   Got 'HOMOOffset' = 0.40847 instead of 0.584065
#   Got 'D-HOMO & A-LUMO offset' = 1.29862 instead of 1.12302
# For acc=Y5, don=PBDB-T, the pairs entry Y5/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.851221 instead of 0.717812
#   Got 'HOMOOffset' = 0.281121 instead of 0.456716
#   Got 'D-HOMO & A-LUMO offset' = 1.50956 instead of 1.33396
# Lucky, but just because BTTPC/PTB7-Th appeared before BTTPC-Br/PTB7-Th.
# Lucky, but just because BTTPC/PBDB-TF appeared before BTTPC-Br/PBDB-TF.
# Lucky, but just because BTTPC/PDCBT-Cl appeared before BTTPC-Br/PDCBT-Cl.
# Lucky, but just because BTTPC/P3HT appeared before BTTPC-Br/P3HT.
# For acc=BTTPC, don=PBDB-T, the pairs entry BTTPC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.828423 instead of 0.695014
#   Got 'HOMOOffset' = 0.289393 instead of 0.464988
#   Got 'D-HOMO & A-LUMO offset' = 1.53236 instead of 1.35676
# Lucky, but just because BTTPC/PBDB-T-2Cl appeared before BTTPC-Br/PBDB-T-2Cl.
# For acc=BTP-PhC6, don=PBDB-T, the pairs entry BTP-PhC6/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.895376 instead of 0.761968
#   Got 'HOMOOffset' = 0.381912 instead of 0.557507
#   Got 'D-HOMO & A-LUMO offset' = 1.4654 instead of 1.28981
# For acc=o-IO1, don=PBDB-T, the pairs entry o-IO1/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.962013 instead of 0.828604
#   Got 'HOMOOffset' = 0.206099 instead of 0.381694
#   Got 'D-HOMO & A-LUMO offset' = 1.39877 instead of 1.22317
# For acc=TPIC-4Cl, don=PBDB-T, the pairs entry TPIC-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.914307 instead of 0.780898
#   Got 'HOMOOffset' = 0.399218 instead of 0.574813
#   Got 'D-HOMO & A-LUMO offset' = 1.44647 instead of 1.27088
# For acc=AQx-2, don=PBDB-T, the pairs entry AQx-2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.946475 instead of 0.813067
#   Got 'HOMOOffset' = 0.45658 instead of 0.632175
#   Got 'D-HOMO & A-LUMO offset' = 1.4143 instead of 1.23871
# For acc=N65-IC, don=PBDB-T, the pairs entry N65-IC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.854949 instead of 0.72154
#   Got 'HOMOOffset' = 0.237202 instead of 0.412797
#   Got 'D-HOMO & A-LUMO offset' = 1.50583 instead of 1.33024
# For acc=BTA43, don=PBDB-T, the pairs entry BTA43/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.559934 instead of 0.426526
#   Got 'HOMOOffset' = 0.016354 instead of 0.191949
#   Got 'D-HOMO & A-LUMO offset' = 1.80084 instead of 1.62525
# Lucky, but just because BTCIC/PTB7-Th appeared before BTCIC-4Cl/PTB7-Th.
# Lucky, but just because BTCIC/PBDB-TF appeared before BTCIC-4Cl/PBDB-TF.
# Lucky, but just because BTCIC/PDCBT-Cl appeared before BTCIC-4Cl/PDCBT-Cl.
# Lucky, but just because BTCIC/P3HT appeared before BTCIC-4Cl/P3HT.
# For acc=BTCIC, don=PBDB-T, the pairs entry BTCIC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.949099 instead of 0.81569
#   Got 'HOMOOffset' = 0.246671 instead of 0.422266
#   Got 'D-HOMO & A-LUMO offset' = 1.41168 instead of 1.23609
# Lucky, but just because BTCIC/PBDB-T-2Cl appeared before BTCIC-4Cl/PBDB-T-2Cl.
# For acc=o-IO2, don=PBDB-T, the pairs entry o-IO2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.860752 instead of 0.727344
#   Got 'HOMOOffset' = 0.125444 instead of 0.30104
#   Got 'D-HOMO & A-LUMO offset' = 1.50003 instead of 1.32443
# For acc=IDST-4F, don=PBDB-T, the pairs entry IDST-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.02306 instead of 0.889654
#   Got 'HOMOOffset' = 0.325693 instead of 0.501288
#   Got 'D-HOMO & A-LUMO offset' = 1.33772 instead of 1.16212
# For acc=BDTN-Th, don=PBDB-T, the pairs entry BDTN-Th/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.859212 instead of 0.725804
#   Got 'HOMOOffset' = 0.213854 instead of 0.389449
#   Got 'D-HOMO & A-LUMO offset' = 1.50157 instead of 1.32597
# For acc=IDTT-TBTA, don=PBDB-T, the pairs entry IDTT-TBTA/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.594889 instead of 0.461481
#   Got 'HOMOOffset' = 0.395871 instead of 0.571466
#   Got 'D-HOMO & A-LUMO offset' = 1.76589 instead of 1.59029
# For acc=BTP-4Cl, don=PBDB-T, the pairs entry BTP-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.01165 instead of 0.878243
#   Got 'HOMOOffset' = 0.51356 instead of 0.689156
#   Got 'D-HOMO & A-LUMO offset' = 1.34913 instead of 1.17353
# For acc=ZY-4Cl, don=PBDB-T, the pairs entry ZY-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.538282 instead of 0.404873
#   Got 'HOMOOffset' = 0.262617 instead of 0.438212
#   Got 'D-HOMO & A-LUMO offset' = 1.8225 instead of 1.6469
# For acc=EH-IDTBR, don=PBDB-T, the pairs entry EH-IDTBR/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.725863 instead of 0.592454
#   Got 'HOMOOffset' = 0.0624773 instead of 0.238072
#   Got 'D-HOMO & A-LUMO offset' = 1.63492 instead of 1.45932
# For acc=BTN-4F, don=PBDB-T, the pairs entry BTN-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.976189 instead of 0.84278
#   Got 'HOMOOffset' = 0.415028 instead of 0.590623
#   Got 'D-HOMO & A-LUMO offset' = 1.38459 instead of 1.209
# For acc=BCDT-4F, don=PBDB-T, the pairs entry BCDT-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.984591 instead of 0.851182
#   Got 'HOMOOffset' = 0.294264 instead of 0.469859
#   Got 'D-HOMO & A-LUMO offset' = 1.37619 instead of 1.20059
# For acc=FDICTF, don=PBDB-T, the pairs entry FDICTF/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.834046 instead of 0.700638
#   Got 'HOMOOffset' = 0.450702 instead of 0.626297
#   Got 'D-HOMO & A-LUMO offset' = 1.52673 instead of 1.35114
# For acc=Y1-4F, don=PBDB-T, the pairs entry Y1-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.946839 instead of 0.81343
#   Got 'HOMOOffset' = 0.446566 instead of 0.622161
#   Got 'D-HOMO & A-LUMO offset' = 1.41394 instead of 1.23835
# For acc=BTCIC-4Cl, don=PBDB-T, the pairs entry BTCIC-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.12413 instead of 0.990717
#   Got 'HOMOOffset' = 0.463927 instead of 0.639522
#   Got 'D-HOMO & A-LUMO offset' = 1.23665 instead of 1.06106
# For acc=NIDT, don=PBDB-T, the pairs entry NIDT/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.513708 instead of 0.3803
#   Got 'HOMOOffset' = 0.1732 instead of 0.348796
#   Got 'D-HOMO & A-LUMO offset' = 1.84707 instead of 1.67148
# For acc=BCDT-4Cl, don=PBDB-T, the pairs entry BCDT-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.00858 instead of 0.875175
#   Got 'HOMOOffset' = 0.327679 instead of 0.503275
#   Got 'D-HOMO & A-LUMO offset' = 1.3522 instead of 1.1766
# For acc=p-IO1, don=PBDB-T, the pairs entry p-IO1/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.918438 instead of 0.785029
#   Got 'HOMOOffset' = 0.153064 instead of 0.328659
#   Got 'D-HOMO & A-LUMO offset' = 1.44234 instead of 1.26675
# For acc=BTA3, don=PBDB-T, the pairs entry BTA3/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.648207 instead of 0.514799
#   Got 'HOMOOffset' = 0.146397 instead of 0.321992
#   Got 'D-HOMO & A-LUMO offset' = 1.71257 instead of 1.53698
# For acc=BTTPC-Br, don=PBDB-T, the pairs entry BTTPC-Br/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.876333 instead of 0.742924
#   Got 'HOMOOffset' = 0.291516 instead of 0.467111
#   Got 'D-HOMO & A-LUMO offset' = 1.48445 instead of 1.30885
# For acc=AQx, don=PTB7-Th, the pairs entry AQx-2/PTB7-Th was wrongly picked!
#   Got 'LUMOOffset' = 0.845797 instead of 0.863866
#   Got 'HOMOOffset' = 0.708721 instead of 0.648556
#   Got 'D-HOMO & A-LUMO offset' = 1.16216 instead of 1.14409
# For acc=AQx, don=PBDB-TF, the pairs entry AQx-2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.946475 instead of 0.964544
#   Got 'HOMOOffset' = 0.45658 instead of 0.396415
#   Got 'D-HOMO & A-LUMO offset' = 1.4143 instead of 1.39623
# For acc=AQx, don=PDCBT-Cl, the pairs entry AQx-2/PDCBT-Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.961066 instead of 0.979135
#   Got 'HOMOOffset' = 0.622678 instead of 0.562514
#   Got 'D-HOMO & A-LUMO offset' = 1.24821 instead of 1.23014
# For acc=AQx, don=P3HT, the pairs entry AQx-2/P3HT was wrongly picked!
#   Got 'LUMOOffset' = 1.73288 instead of 1.75095
#   Got 'HOMOOffset' = 0.593807 instead of 0.533642
#   Got 'D-HOMO & A-LUMO offset' = 1.27708 instead of 1.25901
# For acc=AQx, don=PBDB-T, the pairs entry AQx-2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.946475 instead of 0.831136
#   Got 'HOMOOffset' = 0.45658 instead of 0.572011
#   Got 'D-HOMO & A-LUMO offset' = 1.4143 instead of 1.22064
# For acc=AQx, don=PBDB-T-2Cl, the pairs entry AQx-2/PBDB-T-2Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.947561 instead of 0.96563
#   Got 'HOMOOffset' = 0.389313 instead of 0.329149
#   Got 'D-HOMO & A-LUMO offset' = 1.48157 instead of 1.4635
# For acc=IDF-4F, don=PBDB-T, the pairs entry IDF-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.10581 instead of 0.9724
#   Got 'HOMOOffset' = 0.63544 instead of 0.811035
#   Got 'D-HOMO & A-LUMO offset' = 1.25497 instead of 1.07938
# For acc=Y16, don=PBDB-T, the pairs entry Y16/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.766386 instead of 0.632978
#   Got 'HOMOOffset' = 0.264576 instead of 0.440171
#   Got 'D-HOMO & A-LUMO offset' = 1.59439 instead of 1.4188
# For acc=DTG-IW, don=PBDB-T, the pairs entry DTG-IW/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.00283 instead of 0.869419
#   Got 'HOMOOffset' = 0.442348 instead of 0.617943
#   Got 'D-HOMO & A-LUMO offset' = 1.35795 instead of 1.18236
# For acc=p-IO2, don=PBDB-T, the pairs entry p-IO2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.841692 instead of 0.708283
#   Got 'HOMOOffset' = 0.130288 instead of 0.305883
#   Got 'D-HOMO & A-LUMO offset' = 1.51909 instead of 1.34349
# For acc=BTDT2R, don=PBDB-T, the pairs entry BTDT2R/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.593797 instead of 0.460388
#   Got 'HOMOOffset' = 0.307135 instead of 0.48273
#   Got 'D-HOMO & A-LUMO offset' = 1.76698 instead of 1.59139
# For acc=FO-2F, don=PBDB-T, the pairs entry FO-2F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.00899 instead of 0.875583
#   Got 'HOMOOffset' = 0.591875 instead of 0.76747
#   Got 'D-HOMO & A-LUMO offset' = 1.35179 instead of 1.17619
# For acc=BT6IC-HD-4Cl, don=PBDB-T, the pairs entry BT6IC-HD-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.05937 instead of 0.92596
#   Got 'HOMOOffset' = 0.443246 instead of 0.618841
#   Got 'D-HOMO & A-LUMO offset' = 1.30141 instead of 1.12581
# For acc=ITIC-Th, don=PBDB-T, the pairs entry ITIC-Th/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.899769 instead of 0.76636
#   Got 'HOMOOffset' = 0.341993 instead of 0.517588
#   Got 'D-HOMO & A-LUMO offset' = 1.46101 instead of 1.28542
# For acc=Y11, don=PBDB-T, the pairs entry Y11/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.916533 instead of 0.783124
#   Got 'HOMOOffset' = 0.395381 instead of 0.570976
#   Got 'D-HOMO & A-LUMO offset' = 1.44425 instead of 1.26865
# For acc=CH1007, don=PBDB-T, the pairs entry CH1007/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.993344 instead of 0.859935
#   Got 'HOMOOffset' = 0.445015 instead of 0.62061
#   Got 'D-HOMO & A-LUMO offset' = 1.36744 instead of 1.19184
# For acc=Y15, don=PBDB-T, the pairs entry Y15/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.928556 instead of 0.795147
#   Got 'HOMOOffset' = 0.388633 instead of 0.564228
#   Got 'D-HOMO & A-LUMO offset' = 1.43222 instead of 1.25663
# For acc=F-2F, don=PBDB-T, the pairs entry F-2F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.973658 instead of 0.840249
#   Got 'HOMOOffset' = 0.620528 instead of 0.796123
#   Got 'D-HOMO & A-LUMO offset' = 1.38712 instead of 1.21153
# For acc=BTSe-4F, don=PBDB-T, the pairs entry BTSe-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.06434 instead of 0.930926
#   Got 'HOMOOffset' = 0.520445 instead of 0.69604
#   Got 'D-HOMO & A-LUMO offset' = 1.29644 instead of 1.12085
# For acc=O-IDTBR, don=PBDB-T, the pairs entry O-IDTBR/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.714189 instead of 0.58078
#   Got 'HOMOOffset' = 0.0446539 instead of 0.220249
#   Got 'D-HOMO & A-LUMO offset' = 1.64659 instead of 1.471
# For acc=ITIC, don=PTB7-Th, the pairs entry ITIC-Th/PTB7-Th was wrongly picked!
#   Got 'LUMOOffset' = 0.79909 instead of 0.776495
#   Got 'HOMOOffset' = 0.594133 instead of 0.568364
#   Got 'D-HOMO & A-LUMO offset' = 1.20887 instead of 1.23146
# For acc=ITIC, don=PBDB-TF, the pairs entry ITIC-Th/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.899769 instead of 0.877174
#   Got 'HOMOOffset' = 0.341993 instead of 0.316224
#   Got 'D-HOMO & A-LUMO offset' = 1.46101 instead of 1.48361
# For acc=ITIC, don=PDCBT-Cl, the pairs entry ITIC-Th/PDCBT-Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.91436 instead of 0.891764
#   Got 'HOMOOffset' = 0.508091 instead of 0.482322
#   Got 'D-HOMO & A-LUMO offset' = 1.29491 instead of 1.31751
# For acc=ITIC, don=P3HT, the pairs entry ITIC-Th/P3HT was wrongly picked!
#   Got 'LUMOOffset' = 1.68617 instead of 1.66358
#   Got 'HOMOOffset' = 0.47922 instead of 0.453451
#   Got 'D-HOMO & A-LUMO offset' = 1.32378 instead of 1.34638
# For acc=ITIC, don=PBDB-T, the pairs entry ITIC-Th/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.899769 instead of 0.743765
#   Got 'HOMOOffset' = 0.341993 instead of 0.491819
#   Got 'D-HOMO & A-LUMO offset' = 1.46101 instead of 1.30801
# For acc=ITIC, don=PBDB-T-2Cl, the pairs entry ITIC-Th/PBDB-T-2Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.900854 instead of 0.878259
#   Got 'HOMOOffset' = 0.274726 instead of 0.248957
#   Got 'D-HOMO & A-LUMO offset' = 1.52828 instead of 1.55087
# For acc=ITCC, don=PBDB-T, the pairs entry ITCC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.813292 instead of 0.679883
#   Got 'HOMOOffset' = 0.318536 instead of 0.494132
#   Got 'D-HOMO & A-LUMO offset' = 1.54749 instead of 1.37189
# For acc=i-cc34, don=PBDB-T, the pairs entry i-cc34/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.04452 instead of 0.911114
#   Got 'HOMOOffset' = 0.08509 instead of 0.260685
#   Got 'D-HOMO & A-LUMO offset' = 1.31626 instead of 1.14066
# For acc=CPDT-4F, don=PBDB-T, the pairs entry CPDT-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.991028 instead of 0.85762
#   Got 'HOMOOffset' = 0.461396 instead of 0.636991
#   Got 'D-HOMO & A-LUMO offset' = 1.36975 instead of 1.19416
# For acc=BDTN-BF, don=PBDB-T, the pairs entry BDTN-BF/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.921507 instead of 0.788098
#   Got 'HOMOOffset' = 0.391354 instead of 0.566949
#   Got 'D-HOMO & A-LUMO offset' = 1.43927 instead of 1.26368
# For acc=NIBT, don=PBDB-T, the pairs entry NIBT/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.67694 instead of 0.543531
#   Got 'HOMOOffset' = 0.0640284 instead of 0.239623
#   Got 'D-HOMO & A-LUMO offset' = 1.68384 instead of 1.50824
# For acc=M8, don=PBDB-T, the pairs entry M8/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.925661 instead of 0.792253
#   Got 'HOMOOffset' = 0.409667 instead of 0.585262
#   Got 'D-HOMO & A-LUMO offset' = 1.43512 instead of 1.25952
# For acc=Y1, don=PTB7-Th, the pairs entry Y14/PTB7-Th was wrongly picked!
#   Got 'LUMOOffset' = 0.71286 instead of 0.806029
#   Got 'HOMOOffset' = 0.538105 instead of 0.453532
#   Got 'D-HOMO & A-LUMO offset' = 1.2951 instead of 1.20193
# For acc=Y1, don=PBDB-TF, the pairs entry Y14/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.813538 instead of 0.906708
#   Got 'HOMOOffset' = 0.285964 instead of 0.201391
#   Got 'D-HOMO & A-LUMO offset' = 1.54724 instead of 1.45407
# For acc=Y1, don=PDCBT-Cl, the pairs entry Y14/PDCBT-Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.828129 instead of 0.921299
#   Got 'HOMOOffset' = 0.452063 instead of 0.36749
#   Got 'D-HOMO & A-LUMO offset' = 1.38114 instead of 1.28797
# For acc=Y1, don=P3HT, the pairs entry Y14/P3HT was wrongly picked!
#   Got 'LUMOOffset' = 1.59994 instead of 1.69311
#   Got 'HOMOOffset' = 0.423191 instead of 0.338618
#   Got 'D-HOMO & A-LUMO offset' = 1.41001 instead of 1.31684
# For acc=Y1, don=PBDB-T, the pairs entry Y14/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.813538 instead of 0.773299
#   Got 'HOMOOffset' = 0.285964 instead of 0.376987
#   Got 'D-HOMO & A-LUMO offset' = 1.54724 instead of 1.27848
# For acc=Y1, don=PBDB-T-2Cl, the pairs entry Y14/PBDB-T-2Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.814624 instead of 0.907793
#   Got 'HOMOOffset' = 0.218698 instead of 0.134125
#   Got 'D-HOMO & A-LUMO offset' = 1.61451 instead of 1.52134
# For acc=SNBDT1-F, don=PBDB-T, the pairs entry SNBDT1-F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.895834 instead of 0.762425
#   Got 'HOMOOffset' = 0.186153 instead of 0.361748
#   Got 'D-HOMO & A-LUMO offset' = 1.46495 instead of 1.28935
# For acc=IDTCF, don=PBDB-T, the pairs entry IDTCF/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.11726 instead of 0.983854
#   Got 'HOMOOffset' = 0.778354 instead of 0.95395
#   Got 'D-HOMO & A-LUMO offset' = 1.24352 instead of 1.06792
# For acc=PC70BM, don=PBDB-T, the pairs entry PC70BM/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.02217 instead of 0.88876
#   Got 'HOMOOffset' = 0.659332 instead of 0.834927
#   Got 'D-HOMO & A-LUMO offset' = 1.33861 instead of 1.16301
# For acc=N65-2FIC, don=PBDB-T, the pairs entry N65-2FIC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.992084 instead of 0.858675
#   Got 'HOMOOffset' = 0.365014 instead of 0.540609
#   Got 'D-HOMO & A-LUMO offset' = 1.3687 instead of 1.1931
# For acc=PCBM, don=PBDB-T, the pairs entry PCBM/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.19756 instead of 1.06415
#   Got 'HOMOOffset' = 0.72434 instead of 0.899935
#   Got 'D-HOMO & A-LUMO offset' = 1.16322 instead of 0.987625
# For acc=IDIC, don=PBDB-T, the pairs entry IDIC/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.914752 instead of 0.781343
#   Got 'HOMOOffset' = 0.655441 instead of 0.831036
#   Got 'D-HOMO & A-LUMO offset' = 1.44603 instead of 1.27043
# For acc=TPIC, don=PTB7-Th, the pairs entry TPIC-4Cl/PTB7-Th was wrongly picked!
#   Got 'LUMOOffset' = 0.813628 instead of 0.700537
#   Got 'HOMOOffset' = 0.651359 instead of 0.468117
#   Got 'D-HOMO & A-LUMO offset' = 1.19433 instead of 1.30742
# For acc=TPIC, don=PBDB-TF, the pairs entry TPIC-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.914307 instead of 0.801215
#   Got 'HOMOOffset' = 0.399218 instead of 0.215977
#   Got 'D-HOMO & A-LUMO offset' = 1.44647 instead of 1.55956
# For acc=TPIC, don=PDCBT-Cl, the pairs entry TPIC-4Cl/PDCBT-Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.928898 instead of 0.815806
#   Got 'HOMOOffset' = 0.565317 instead of 0.382075
#   Got 'D-HOMO & A-LUMO offset' = 1.28037 instead of 1.39347
# For acc=TPIC, don=P3HT, the pairs entry TPIC-4Cl/P3HT was wrongly picked!
#   Got 'LUMOOffset' = 1.70071 instead of 1.58762
#   Got 'HOMOOffset' = 0.536445 instead of 0.353204
#   Got 'D-HOMO & A-LUMO offset' = 1.30925 instead of 1.42234
# For acc=TPIC, don=PBDB-T, the pairs entry TPIC-4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.914307 instead of 0.667807
#   Got 'HOMOOffset' = 0.399218 instead of 0.391572
#   Got 'D-HOMO & A-LUMO offset' = 1.44647 instead of 1.38397
# For acc=TPIC, don=PBDB-T-2Cl, the pairs entry TPIC-4Cl/PBDB-T-2Cl was wrongly picked!
#   Got 'LUMOOffset' = 0.915392 instead of 0.802301
#   Got 'HOMOOffset' = 0.331952 instead of 0.14871
#   Got 'D-HOMO & A-LUMO offset' = 1.51374 instead of 1.62683
# For acc=F-H, don=PBDB-T, the pairs entry F-H/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.821904 instead of 0.688495
#   Got 'HOMOOffset' = 0.463927 instead of 0.639522
#   Got 'D-HOMO & A-LUMO offset' = 1.53888 instead of 1.36328
# For acc=IT-4F, don=PBDB-T, the pairs entry IT-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.973895 instead of 0.840487
#   Got 'HOMOOffset' = 0.51269 instead of 0.688285
#   Got 'D-HOMO & A-LUMO offset' = 1.38688 instead of 1.21129
# For acc=Y2, don=PBDB-T, the pairs entry Y2/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.832723 instead of 0.699315
#   Got 'HOMOOffset' = 0.301665 instead of 0.47726
#   Got 'D-HOMO & A-LUMO offset' = 1.52806 instead of 1.35246
# For acc=SeTIC4Cl, don=PBDB-T, the pairs entry SeTIC4Cl/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 1.01058 instead of 0.877171
#   Got 'HOMOOffset' = 0.454267 instead of 0.629862
#   Got 'D-HOMO & A-LUMO offset' = 1.3502 instead of 1.1746
# For acc=TPIC-4F, don=PBDB-T, the pairs entry TPIC-4F/PBDB-TF was wrongly picked!
#   Got 'LUMOOffset' = 0.897704 instead of 0.764295
#   Got 'HOMOOffset' = 0.412334 instead of 0.587929
#   Got 'D-HOMO & A-LUMO offset' = 1.46308 instead of 1.28748
# 93 out of 438 were bad!

# %% [markdown]
# Thus, in 93 of 438 cases, the wrong offsets were taken.

# %% [markdown]
# ## Mix-up of 'AbsFOM'

# %% [markdown]
# There is a similar bug in lines 1127, 1128, where tha AbsFOM paramter is selected.

# %%
TDDFT_absFOM = pd.read_csv('../data_csv/TDDFT_absorptionFOM_data.csv')      
TDDFT_pairs = TDDFT_absFOM['Donor/acceptor pair'].tolist()
abs_FOM = TDDFT_absFOM['FOM 1.5G AM'].tolist()

# %%
bad = 0; good = 0;
for i in range(len(acceptors)):
    for x in range(len(donors)): 
        donors[x] = donors[x].split('_',1)[0]
        cands = [] # New variable to keep track of collisions
        p_true = None
        for pair in range(len(TDDFT_pairs)):
            # Faulty criterion:
            if str(acceptors[i]) in str(TDDFT_pairs[pair]):
                if str(donors[x]) in str(TDDFT_pairs[pair]):
                    cands.append(pair)
            # Correct criterion:
            don_str, acc_str = TDDFT_pairs[pair].split(' and ')
            don_str = don_str.split('_')[0]
            if acc_str == acceptors[i] and don_str == donors[x]:
                p_true = pair
        p_picked = cands[0]
        if len(cands) != 1:
            print(f"Multiple hits for don={donors[x]} and acc={acceptors[i]}:\n\t {[TDDFT_pairs[p] for p in cands]}")
            print(f"Correct: '{TDDFT_pairs[p_true]}'")
            if TDDFT_pairs[p_true]==TDDFT_pairs[p_picked]:
                print('Lucky!')
                good += 1
            else:
                bad += 1
                print(f"  Got 'AbsFOM' = {abs_FOM[p_picked]:g} instead of {abs_FOM[p_true]:g}")

        else:
            assert p_picked==p_true
            good += 1
print(f"{bad} out of {good+bad} were bad!")
# Out:
# Multiple hits for don=PBDB-T and acc=BTA53:
# 	 ['PBDB-TF_dimer and BTA53', 'PBDB-T_tetra and BTA53', 'PBDB-T-2Cl_dimer and BTA53']
# Correct: 'PBDB-T_tetra and BTA53'
#   Got 'AbsFOM' = 46.8232 instead of 69.9927
# Multiple hits for don=PBDB-T and acc=i-cc23:
# 	 ['PBDB-TF_dimer and i-cc23', 'PBDB-T_tetra and i-cc23', 'PBDB-T-2Cl_dimer and i-cc23']
# Correct: 'PBDB-T_tetra and i-cc23'
#   Got 'AbsFOM' = 40.861 instead of 64.0306
# Multiple hits for don=PBDB-T and acc=Y14:
# 	 ['PBDB-TF_dimer and Y14', 'PBDB-T_tetra and Y14', 'PBDB-T-2Cl_dimer and Y14']
# Correct: 'PBDB-T_tetra and Y14'
#   Got 'AbsFOM' = 47.6944 instead of 70.8639
# Multiple hits for don=PBDB-T and acc=IPTBO-4Cl:
# 	 ['PBDB-TF_dimer and IPTBO-4Cl', 'PBDB-T_tetra and IPTBO-4Cl', 'PBDB-T-2Cl_dimer and IPTBO-4Cl']
# Correct: 'PBDB-T_tetra and IPTBO-4Cl'
#   Got 'AbsFOM' = 52.7352 instead of 75.9047
# Multiple hits for don=PBDB-T and acc=H2:
# 	 ['PBDB-TF_dimer and H2', 'PBDB-T_tetra and H2', 'PBDB-T-2Cl_dimer and H2']
# Correct: 'PBDB-T_tetra and H2'
#   Got 'AbsFOM' = 48.1532 instead of 71.3228
# Multiple hits for don=PBDB-T and acc=NITV:
# 	 ['PBDB-TF_dimer and NITV', 'PBDB-T_tetra and NITV', 'PBDB-T-2Cl_dimer and NITV']
# Correct: 'PBDB-T_tetra and NITV'
#   Got 'AbsFOM' = 46.5879 instead of 69.7575
# Multiple hits for don=PBDB-T and acc=IDF-IC:
# 	 ['PBDB-TF_dimer and IDF-IC', 'PBDB-T_tetra and IDF-IC', 'PBDB-T-2Cl_dimer and IDF-IC']
# Correct: 'PBDB-T_tetra and IDF-IC'
#   Got 'AbsFOM' = 41.2494 instead of 64.419
# Multiple hits for don=PBDB-T and acc=Y6:
# 	 ['PBDB-TF_dimer and Y6', 'PBDB-T_tetra and Y6', 'PBDB-T-2Cl_dimer and Y6']
# Correct: 'PBDB-T_tetra and Y6'
#   Got 'AbsFOM' = 46.7669 instead of 69.9364
# Multiple hits for don=PBDB-T and acc=M34:
# 	 ['PBDB-TF_dimer and M34', 'PBDB-T_tetra and M34', 'PBDB-T-2Cl_dimer and M34']
# Correct: 'PBDB-T_tetra and M34'
#   Got 'AbsFOM' = 55.3699 instead of 78.5394
# Multiple hits for don=PTB7-Th and acc=SeTIC:
# 	 ['PTB7-Th_tetra and SeTIC', 'PTB7-Th_tetra and SeTIC4Cl']
# Correct: 'PTB7-Th_tetra and SeTIC'
# Lucky!
# Multiple hits for don=PBDB-TF and acc=SeTIC:
# 	 ['PBDB-TF_dimer and SeTIC', 'PBDB-TF_dimer and SeTIC4Cl']
# Correct: 'PBDB-TF_dimer and SeTIC'
# Lucky!
# Multiple hits for don=PDCBT-Cl and acc=SeTIC:
# 	 ['PDCBT-Cl_tetra and SeTIC', 'PDCBT-Cl_tetra and SeTIC4Cl']
# Correct: 'PDCBT-Cl_tetra and SeTIC'
# Lucky!
# Multiple hits for don=P3HT and acc=SeTIC:
# 	 ['P3HT and SeTIC', 'P3HT and SeTIC4Cl']
# Correct: 'P3HT and SeTIC'
# Lucky!
# Multiple hits for don=PBDB-T and acc=SeTIC:
# 	 ['PBDB-TF_dimer and SeTIC', 'PBDB-T_tetra and SeTIC', 'PBDB-T-2Cl_dimer and SeTIC', 'PBDB-TF_dimer and SeTIC4Cl', 'PBDB-T_tetra and SeTIC4Cl', 'PBDB-T-2Cl_dimer and SeTIC4Cl']
# Correct: 'PBDB-T_tetra and SeTIC'
#   Got 'AbsFOM' = 41.1044 instead of 64.274
# Multiple hits for don=PBDB-T-2Cl and acc=SeTIC:
# 	 ['PBDB-T-2Cl_dimer and SeTIC', 'PBDB-T-2Cl_dimer and SeTIC4Cl']
# Correct: 'PBDB-T-2Cl_dimer and SeTIC'
# Lucky!
# Multiple hits for don=PBDB-T and acc=N3:
# 	 ['PBDB-TF_dimer and N3', 'PBDB-T_tetra and N3', 'PBDB-T-2Cl_dimer and N3']
# Correct: 'PBDB-T_tetra and N3'
#   Got 'AbsFOM' = 45.1606 instead of 68.3302
# Multiple hits for don=PBDB-T and acc=CPDT-4Cl:
# 	 ['PBDB-TF_dimer and CPDT-4Cl', 'PBDB-T_tetra and CPDT-4Cl', 'PBDB-T-2Cl_dimer and CPDT-4Cl']
# Correct: 'PBDB-T_tetra and CPDT-4Cl'
#   Got 'AbsFOM' = 45.8403 instead of 69.0098
# Multiple hits for don=PBDB-T and acc=Y5:
# 	 ['PBDB-TF_dimer and Y5', 'PBDB-T_tetra and Y5', 'PBDB-T-2Cl_dimer and Y5']
# Correct: 'PBDB-T_tetra and Y5'
#   Got 'AbsFOM' = 46.0091 instead of 69.1787
# Multiple hits for don=PTB7-Th and acc=BTTPC:
# 	 ['PTB7-Th_tetra and BTTPC', 'PTB7-Th_tetra and BTTPC-Br']
# Correct: 'PTB7-Th_tetra and BTTPC'
# Lucky!
# Multiple hits for don=PBDB-TF and acc=BTTPC:
# 	 ['PBDB-TF_dimer and BTTPC', 'PBDB-TF_dimer and BTTPC-Br']
# Correct: 'PBDB-TF_dimer and BTTPC'
# Lucky!
# Multiple hits for don=PDCBT-Cl and acc=BTTPC:
# 	 ['PDCBT-Cl_tetra and BTTPC', 'PDCBT-Cl_tetra and BTTPC-Br']
# Correct: 'PDCBT-Cl_tetra and BTTPC'
# Lucky!
# Multiple hits for don=P3HT and acc=BTTPC:
# 	 ['P3HT and BTTPC', 'P3HT and BTTPC-Br']
# Correct: 'P3HT and BTTPC'
# Lucky!
# Multiple hits for don=PBDB-T and acc=BTTPC:
# 	 ['PBDB-TF_dimer and BTTPC', 'PBDB-T_tetra and BTTPC', 'PBDB-T-2Cl_dimer and BTTPC', 'PBDB-TF_dimer and BTTPC-Br', 'PBDB-T_tetra and BTTPC-Br', 'PBDB-T-2Cl_dimer and BTTPC-Br']
# Correct: 'PBDB-T_tetra and BTTPC'
#   Got 'AbsFOM' = 49.4882 instead of 72.6578
# Multiple hits for don=PBDB-T-2Cl and acc=BTTPC:
# 	 ['PBDB-T-2Cl_dimer and BTTPC', 'PBDB-T-2Cl_dimer and BTTPC-Br']
# Correct: 'PBDB-T-2Cl_dimer and BTTPC'
# Lucky!
# Multiple hits for don=PBDB-T and acc=BTP-PhC6:
# 	 ['PBDB-TF_dimer and BTP-PhC6', 'PBDB-T_tetra and BTP-PhC6', 'PBDB-T-2Cl_dimer and BTP-PhC6']
# Correct: 'PBDB-T_tetra and BTP-PhC6'
#   Got 'AbsFOM' = 51.6924 instead of 74.862
# Multiple hits for don=PBDB-T and acc=o-IO1:
# 	 ['PBDB-TF_dimer and o-IO1', 'PBDB-T_tetra and o-IO1', 'PBDB-T-2Cl_dimer and o-IO1']
# Correct: 'PBDB-T_tetra and o-IO1'
#   Got 'AbsFOM' = 54.3966 instead of 77.5661
# Multiple hits for don=PBDB-T and acc=TPIC-4Cl:
# 	 ['PBDB-TF_dimer and TPIC-4Cl', 'PBDB-T_tetra and TPIC-4Cl', 'PBDB-T-2Cl_dimer and TPIC-4Cl']
# Correct: 'PBDB-T_tetra and TPIC-4Cl'
#   Got 'AbsFOM' = 45.359 instead of 68.5286
# Multiple hits for don=PBDB-T and acc=AQx-2:
# 	 ['PBDB-TF_dimer and AQx-2', 'PBDB-T_tetra and AQx-2', 'PBDB-T-2Cl_dimer and AQx-2']
# Correct: 'PBDB-T_tetra and AQx-2'
#   Got 'AbsFOM' = 47.7647 instead of 70.9343
# Multiple hits for don=PBDB-T and acc=N65-IC:
# 	 ['PBDB-TF_dimer and N65-IC', 'PBDB-T_tetra and N65-IC', 'PBDB-T-2Cl_dimer and N65-IC']
# Correct: 'PBDB-T_tetra and N65-IC'
#   Got 'AbsFOM' = 41.8641 instead of 65.0336
# Multiple hits for don=PBDB-T and acc=BTA43:
# 	 ['PBDB-TF_dimer and BTA43', 'PBDB-T_tetra and BTA43', 'PBDB-T-2Cl_dimer and BTA43']
# Correct: 'PBDB-T_tetra and BTA43'
#   Got 'AbsFOM' = 53.7744 instead of 76.9439
# Multiple hits for don=PTB7-Th and acc=BTCIC:
# 	 ['PTB7-Th_tetra and BTCIC', 'PTB7-Th_tetra and BTCIC-4Cl']
# Correct: 'PTB7-Th_tetra and BTCIC'
# Lucky!
# Multiple hits for don=PBDB-TF and acc=BTCIC:
# 	 ['PBDB-TF_dimer and BTCIC', 'PBDB-TF_dimer and BTCIC-4Cl']
# Correct: 'PBDB-TF_dimer and BTCIC'
# Lucky!
# Multiple hits for don=PDCBT-Cl and acc=BTCIC:
# 	 ['PDCBT-Cl_tetra and BTCIC', 'PDCBT-Cl_tetra and BTCIC-4Cl']
# Correct: 'PDCBT-Cl_tetra and BTCIC'
# Lucky!
# Multiple hits for don=P3HT and acc=BTCIC:
# 	 ['P3HT and BTCIC', 'P3HT and BTCIC-4Cl']
# Correct: 'P3HT and BTCIC'
# Lucky!
# Multiple hits for don=PBDB-T and acc=BTCIC:
# 	 ['PBDB-TF_dimer and BTCIC', 'PBDB-T_tetra and BTCIC', 'PBDB-T-2Cl_dimer and BTCIC', 'PBDB-TF_dimer and BTCIC-4Cl', 'PBDB-T_tetra and BTCIC-4Cl', 'PBDB-T-2Cl_dimer and BTCIC-4Cl']
# Correct: 'PBDB-T_tetra and BTCIC'
#   Got 'AbsFOM' = 42.525 instead of 65.6945
# Multiple hits for don=PBDB-T-2Cl and acc=BTCIC:
# 	 ['PBDB-T-2Cl_dimer and BTCIC', 'PBDB-T-2Cl_dimer and BTCIC-4Cl']
# Correct: 'PBDB-T-2Cl_dimer and BTCIC'
# Lucky!
# Multiple hits for don=PBDB-T and acc=o-IO2:
# 	 ['PBDB-TF_dimer and o-IO2', 'PBDB-T_tetra and o-IO2', 'PBDB-T-2Cl_dimer and o-IO2']
# Correct: 'PBDB-T_tetra and o-IO2'
#   Got 'AbsFOM' = 41.9794 instead of 65.149
# Multiple hits for don=PBDB-T and acc=IDST-4F:
# 	 ['PBDB-TF_dimer and IDST-4F', 'PBDB-T_tetra and IDST-4F', 'PBDB-T-2Cl_dimer and IDST-4F']
# Correct: 'PBDB-T_tetra and IDST-4F'
#   Got 'AbsFOM' = 42.0968 instead of 65.2663
# Multiple hits for don=PBDB-T and acc=BDTN-Th:
# 	 ['PBDB-TF_dimer and BDTN-Th', 'PBDB-T_tetra and BDTN-Th', 'PBDB-T-2Cl_dimer and BDTN-Th']
# Correct: 'PBDB-T_tetra and BDTN-Th'
#   Got 'AbsFOM' = 53.6441 instead of 76.8137
# Multiple hits for don=PBDB-T and acc=IDTT-TBTA:
# 	 ['PBDB-TF_dimer and IDTT-TBTA', 'PBDB-T_tetra and IDTT-TBTA', 'PBDB-T-2Cl_dimer and IDTT-TBTA']
# Correct: 'PBDB-T_tetra and IDTT-TBTA'
#   Got 'AbsFOM' = 35.4395 instead of 58.609
# Multiple hits for don=PBDB-T and acc=BTP-4Cl:
# 	 ['PBDB-TF_dimer and BTP-4Cl', 'PBDB-T_tetra and BTP-4Cl', 'PBDB-T-2Cl_dimer and BTP-4Cl']
# Correct: 'PBDB-T_tetra and BTP-4Cl'
#   Got 'AbsFOM' = 49.9826 instead of 73.1522
# Multiple hits for don=PBDB-T and acc=ZY-4Cl:
# 	 ['PBDB-TF_dimer and ZY-4Cl', 'PBDB-T_tetra and ZY-4Cl', 'PBDB-T-2Cl_dimer and ZY-4Cl']
# Correct: 'PBDB-T_tetra and ZY-4Cl'
#   Got 'AbsFOM' = 45.2431 instead of 68.4126
# Multiple hits for don=PBDB-T and acc=EH-IDTBR:
# 	 ['PBDB-TF_dimer and EH-IDTBR', 'PBDB-T_tetra and EH-IDTBR', 'PBDB-T-2Cl_dimer and EH-IDTBR']
# Correct: 'PBDB-T_tetra and EH-IDTBR'
#   Got 'AbsFOM' = 48.651 instead of 71.8205
# Multiple hits for don=PBDB-T and acc=BTN-4F:
# 	 ['PBDB-TF_dimer and BTN-4F', 'PBDB-T_tetra and BTN-4F', 'PBDB-T-2Cl_dimer and BTN-4F']
# Correct: 'PBDB-T_tetra and BTN-4F'
#   Got 'AbsFOM' = 47.1588 instead of 70.3284
# Multiple hits for don=PBDB-T and acc=BCDT-4F:
# 	 ['PBDB-TF_dimer and BCDT-4F', 'PBDB-T_tetra and BCDT-4F', 'PBDB-T-2Cl_dimer and BCDT-4F']
# Correct: 'PBDB-T_tetra and BCDT-4F'
#   Got 'AbsFOM' = 40.918 instead of 64.0876
# Multiple hits for don=PBDB-T and acc=FDICTF:
# 	 ['PBDB-TF_dimer and FDICTF', 'PBDB-T_tetra and FDICTF', 'PBDB-T-2Cl_dimer and FDICTF']
# Correct: 'PBDB-T_tetra and FDICTF'
#   Got 'AbsFOM' = 43.0051 instead of 66.1747
# Multiple hits for don=PBDB-T and acc=Y1-4F:
# 	 ['PBDB-TF_dimer and Y1-4F', 'PBDB-T_tetra and Y1-4F', 'PBDB-T-2Cl_dimer and Y1-4F']
# Correct: 'PBDB-T_tetra and Y1-4F'
#   Got 'AbsFOM' = 46.3313 instead of 69.5008
# Multiple hits for don=PBDB-T and acc=BTCIC-4Cl:
# 	 ['PBDB-TF_dimer and BTCIC-4Cl', 'PBDB-T_tetra and BTCIC-4Cl', 'PBDB-T-2Cl_dimer and BTCIC-4Cl']
# Correct: 'PBDB-T_tetra and BTCIC-4Cl'
#   Got 'AbsFOM' = 47.6777 instead of 70.8473
# Multiple hits for don=PBDB-T and acc=NIDT:
# 	 ['PBDB-TF_dimer and NIDT', 'PBDB-T_tetra and NIDT', 'PBDB-T-2Cl_dimer and NIDT']
# Correct: 'PBDB-T_tetra and NIDT'
#   Got 'AbsFOM' = 53.5422 instead of 76.7118
# Multiple hits for don=PBDB-T and acc=BCDT-4Cl:
# 	 ['PBDB-TF_dimer and BCDT-4Cl', 'PBDB-T_tetra and BCDT-4Cl', 'PBDB-T-2Cl_dimer and BCDT-4Cl']
# Correct: 'PBDB-T_tetra and BCDT-4Cl'
#   Got 'AbsFOM' = 40.0992 instead of 63.2688
# Multiple hits for don=PBDB-T and acc=p-IO1:
# 	 ['PBDB-TF_dimer and p-IO1', 'PBDB-T_tetra and p-IO1', 'PBDB-T-2Cl_dimer and p-IO1']
# Correct: 'PBDB-T_tetra and p-IO1'
#   Got 'AbsFOM' = 54.6658 instead of 77.8354
# Multiple hits for don=PBDB-T and acc=BTA3:
# 	 ['PBDB-TF_dimer and BTA3', 'PBDB-T_tetra and BTA3', 'PBDB-T-2Cl_dimer and BTA3']
# Correct: 'PBDB-T_tetra and BTA3'
#   Got 'AbsFOM' = 50.049 instead of 73.2186
# Multiple hits for don=PBDB-T and acc=BTTPC-Br:
# 	 ['PBDB-TF_dimer and BTTPC-Br', 'PBDB-T_tetra and BTTPC-Br', 'PBDB-T-2Cl_dimer and BTTPC-Br']
# Correct: 'PBDB-T_tetra and BTTPC-Br'
#   Got 'AbsFOM' = 49.9463 instead of 73.1159
# Multiple hits for don=PTB7-Th and acc=AQx:
# 	 ['PTB7-Th_tetra and AQx-2', 'PTB7-Th_tetra and AQx']
# Correct: 'PTB7-Th_tetra and AQx'
#   Got 'AbsFOM' = 54.0785 instead of 59.547
# Multiple hits for don=PBDB-TF and acc=AQx:
# 	 ['PBDB-TF_dimer and AQx-2', 'PBDB-TF_dimer and AQx']
# Correct: 'PBDB-TF_dimer and AQx'
#   Got 'AbsFOM' = 47.7647 instead of 53.2332
# Multiple hits for don=PDCBT-Cl and acc=AQx:
# 	 ['PDCBT-Cl_tetra and AQx-2', 'PDCBT-Cl_tetra and AQx']
# Correct: 'PDCBT-Cl_tetra and AQx'
#   Got 'AbsFOM' = 45.1864 instead of 50.6549
# Multiple hits for don=P3HT and acc=AQx:
# 	 ['P3HT and AQx-2', 'P3HT and AQx']
# Correct: 'P3HT and AQx'
#   Got 'AbsFOM' = 37.5284 instead of 42.9969
# Multiple hits for don=PBDB-T and acc=AQx:
# 	 ['PBDB-TF_dimer and AQx-2', 'PBDB-T_tetra and AQx-2', 'PBDB-T-2Cl_dimer and AQx-2', 'PBDB-TF_dimer and AQx', 'PBDB-T_tetra and AQx', 'PBDB-T-2Cl_dimer and AQx']
# Correct: 'PBDB-T_tetra and AQx'
#   Got 'AbsFOM' = 47.7647 instead of 76.4027
# Multiple hits for don=PBDB-T-2Cl and acc=AQx:
# 	 ['PBDB-T-2Cl_dimer and AQx-2', 'PBDB-T-2Cl_dimer and AQx']
# Correct: 'PBDB-T-2Cl_dimer and AQx'
#   Got 'AbsFOM' = 45.9106 instead of 51.3791
# Multiple hits for don=PBDB-T and acc=IDF-4F:
# 	 ['PBDB-TF_dimer and IDF-4F', 'PBDB-T_tetra and IDF-4F', 'PBDB-T-2Cl_dimer and IDF-4F']
# Correct: 'PBDB-T_tetra and IDF-4F'
#   Got 'AbsFOM' = 45.6166 instead of 68.7862
# Multiple hits for don=PBDB-T and acc=Y16:
# 	 ['PBDB-TF_dimer and Y16', 'PBDB-T_tetra and Y16', 'PBDB-T-2Cl_dimer and Y16']
# Correct: 'PBDB-T_tetra and Y16'
#   Got 'AbsFOM' = 46.9188 instead of 70.0883
# Multiple hits for don=PBDB-T and acc=DTG-IW:
# 	 ['PBDB-TF_dimer and DTG-IW', 'PBDB-T_tetra and DTG-IW', 'PBDB-T-2Cl_dimer and DTG-IW']
# Correct: 'PBDB-T_tetra and DTG-IW'
#   Got 'AbsFOM' = 45.01 instead of 68.1796
# Multiple hits for don=PBDB-T and acc=p-IO2:
# 	 ['PBDB-TF_dimer and p-IO2', 'PBDB-T_tetra and p-IO2', 'PBDB-T-2Cl_dimer and p-IO2']
# Correct: 'PBDB-T_tetra and p-IO2'
#   Got 'AbsFOM' = 51.1007 instead of 74.2702
# Multiple hits for don=PBDB-T and acc=BTDT2R:
# 	 ['PBDB-TF_dimer and BTDT2R', 'PBDB-T_tetra and BTDT2R', 'PBDB-T-2Cl_dimer and BTDT2R']
# Correct: 'PBDB-T_tetra and BTDT2R'
#   Got 'AbsFOM' = 41.5326 instead of 64.7022
# Multiple hits for don=PBDB-T and acc=FO-2F:
# 	 ['PBDB-TF_dimer and FO-2F', 'PBDB-T_tetra and FO-2F', 'PBDB-T-2Cl_dimer and FO-2F']
# Correct: 'PBDB-T_tetra and FO-2F'
#   Got 'AbsFOM' = 46.0043 instead of 69.1739
# Multiple hits for don=PBDB-T and acc=BT6IC-HD-4Cl:
# 	 ['PBDB-TF_dimer and BT6IC-HD-4Cl', 'PBDB-T_tetra and BT6IC-HD-4Cl', 'PBDB-T-2Cl_dimer and BT6IC-HD-4Cl']
# Correct: 'PBDB-T_tetra and BT6IC-HD-4Cl'
#   Got 'AbsFOM' = 49.874 instead of 73.0436
# Multiple hits for don=PBDB-T and acc=ITIC-Th:
# 	 ['PBDB-TF_dimer and ITIC-Th', 'PBDB-T_tetra and ITIC-Th', 'PBDB-T-2Cl_dimer and ITIC-Th']
# Correct: 'PBDB-T_tetra and ITIC-Th'
#   Got 'AbsFOM' = 44.6071 instead of 67.7767
# Multiple hits for don=PBDB-T and acc=Y11:
# 	 ['PBDB-TF_dimer and Y11', 'PBDB-T_tetra and Y11', 'PBDB-T-2Cl_dimer and Y11']
# Correct: 'PBDB-T_tetra and Y11'
#   Got 'AbsFOM' = 46.7352 instead of 69.9047
# Multiple hits for don=PBDB-T and acc=CH1007:
# 	 ['PBDB-TF_dimer and CH1007', 'PBDB-T_tetra and CH1007', 'PBDB-T-2Cl_dimer and CH1007']
# Correct: 'PBDB-T_tetra and CH1007'
#   Got 'AbsFOM' = 43.9215 instead of 67.0911
# Multiple hits for don=PBDB-T and acc=Y15:
# 	 ['PBDB-TF_dimer and Y15', 'PBDB-T_tetra and Y15', 'PBDB-T-2Cl_dimer and Y15']
# Correct: 'PBDB-T_tetra and Y15'
#   Got 'AbsFOM' = 48.0119 instead of 71.1815
# Multiple hits for don=PBDB-T and acc=F-2F:
# 	 ['PBDB-TF_dimer and F-2F', 'PBDB-T_tetra and F-2F', 'PBDB-T-2Cl_dimer and F-2F']
# Correct: 'PBDB-T_tetra and F-2F'
#   Got 'AbsFOM' = 42.6409 instead of 65.8105
# Multiple hits for don=PBDB-T and acc=BTSe-4F:
# 	 ['PBDB-TF_dimer and BTSe-4F', 'PBDB-T_tetra and BTSe-4F', 'PBDB-T-2Cl_dimer and BTSe-4F']
# Correct: 'PBDB-T_tetra and BTSe-4F'
#   Got 'AbsFOM' = 49.8784 instead of 73.048
# Multiple hits for don=PBDB-T and acc=O-IDTBR:
# 	 ['PBDB-TF_dimer and O-IDTBR', 'PBDB-T_tetra and O-IDTBR', 'PBDB-T-2Cl_dimer and O-IDTBR']
# Correct: 'PBDB-T_tetra and O-IDTBR'
#   Got 'AbsFOM' = 45.4439 instead of 68.6134
# Multiple hits for don=PTB7-Th and acc=ITIC:
# 	 ['PTB7-Th_tetra and ITIC-Th', 'PTB7-Th_tetra and ITIC']
# Correct: 'PTB7-Th_tetra and ITIC'
#   Got 'AbsFOM' = 50.9209 instead of 47.3739
# Multiple hits for don=PBDB-TF and acc=ITIC:
# 	 ['PBDB-TF_dimer and ITIC-Th', 'PBDB-TF_dimer and ITIC']
# Correct: 'PBDB-TF_dimer and ITIC'
#   Got 'AbsFOM' = 44.6071 instead of 41.0601
# Multiple hits for don=PDCBT-Cl and acc=ITIC:
# 	 ['PDCBT-Cl_tetra and ITIC-Th', 'PDCBT-Cl_tetra and ITIC']
# Correct: 'PDCBT-Cl_tetra and ITIC'
#   Got 'AbsFOM' = 42.0288 instead of 38.4818
# Multiple hits for don=P3HT and acc=ITIC:
# 	 ['P3HT and ITIC-Th', 'P3HT and ITIC']
# Correct: 'P3HT and ITIC'
#   Got 'AbsFOM' = 34.3708 instead of 30.8238
# Multiple hits for don=PBDB-T and acc=ITIC:
# 	 ['PBDB-TF_dimer and ITIC-Th', 'PBDB-T_tetra and ITIC-Th', 'PBDB-T-2Cl_dimer and ITIC-Th', 'PBDB-TF_dimer and ITIC', 'PBDB-T_tetra and ITIC', 'PBDB-T-2Cl_dimer and ITIC']
# Correct: 'PBDB-T_tetra and ITIC'
#   Got 'AbsFOM' = 44.6071 instead of 64.2296
# Multiple hits for don=PBDB-T-2Cl and acc=ITIC:
# 	 ['PBDB-T-2Cl_dimer and ITIC-Th', 'PBDB-T-2Cl_dimer and ITIC']
# Correct: 'PBDB-T-2Cl_dimer and ITIC'
#   Got 'AbsFOM' = 42.753 instead of 39.206
# Multiple hits for don=PBDB-T and acc=ITCC:
# 	 ['PBDB-TF_dimer and ITCC', 'PBDB-T_tetra and ITCC', 'PBDB-T-2Cl_dimer and ITCC']
# Correct: 'PBDB-T_tetra and ITCC'
#   Got 'AbsFOM' = 49.5955 instead of 72.7651
# Multiple hits for don=PBDB-T and acc=i-cc34:
# 	 ['PBDB-TF_dimer and i-cc34', 'PBDB-T_tetra and i-cc34', 'PBDB-T-2Cl_dimer and i-cc34']
# Correct: 'PBDB-T_tetra and i-cc34'
#   Got 'AbsFOM' = 38.723 instead of 61.8926
# Multiple hits for don=PBDB-T and acc=CPDT-4F:
# 	 ['PBDB-TF_dimer and CPDT-4F', 'PBDB-T_tetra and CPDT-4F', 'PBDB-T-2Cl_dimer and CPDT-4F']
# Correct: 'PBDB-T_tetra and CPDT-4F'
#   Got 'AbsFOM' = 31.4765 instead of 54.646
# Multiple hits for don=PBDB-T and acc=BDTN-BF:
# 	 ['PBDB-TF_dimer and BDTN-BF', 'PBDB-T_tetra and BDTN-BF', 'PBDB-T-2Cl_dimer and BDTN-BF']
# Correct: 'PBDB-T_tetra and BDTN-BF'
#   Got 'AbsFOM' = 52.6034 instead of 75.773
# Multiple hits for don=PBDB-T and acc=NIBT:
# 	 ['PBDB-TF_dimer and NIBT', 'PBDB-T_tetra and NIBT', 'PBDB-T-2Cl_dimer and NIBT']
# Correct: 'PBDB-T_tetra and NIBT'
#   Got 'AbsFOM' = 47.6569 instead of 70.8265
# Multiple hits for don=PBDB-T and acc=M8:
# 	 ['PBDB-TF_dimer and M8', 'PBDB-T_tetra and M8', 'PBDB-T-2Cl_dimer and M8']
# Correct: 'PBDB-T_tetra and M8'
#   Got 'AbsFOM' = 48.7784 instead of 71.9479
# Multiple hits for don=PTB7-Th and acc=Y1:
# 	 ['PTB7-Th_tetra and Y14', 'PTB7-Th_tetra and Y1-4F', 'PTB7-Th_tetra and Y16', 'PTB7-Th_tetra and Y11', 'PTB7-Th_tetra and Y15', 'PTB7-Th_tetra and Y1']
# Correct: 'PTB7-Th_tetra and Y1'
#   Got 'AbsFOM' = 54.0082 instead of 51.7906
# Multiple hits for don=PBDB-TF and acc=Y1:
# 	 ['PBDB-TF_dimer and Y14', 'PBDB-TF_dimer and Y1-4F', 'PBDB-TF_dimer and Y16', 'PBDB-TF_dimer and Y11', 'PBDB-TF_dimer and Y15', 'PBDB-TF_dimer and Y1']
# Correct: 'PBDB-TF_dimer and Y1'
#   Got 'AbsFOM' = 47.6944 instead of 45.4768
# Multiple hits for don=PDCBT-Cl and acc=Y1:
# 	 ['PDCBT-Cl_tetra and Y14', 'PDCBT-Cl_tetra and Y1-4F', 'PDCBT-Cl_tetra and Y16', 'PDCBT-Cl_tetra and Y11', 'PDCBT-Cl_tetra and Y15', 'PDCBT-Cl_tetra and Y1']
# Correct: 'PDCBT-Cl_tetra and Y1'
#   Got 'AbsFOM' = 45.1161 instead of 42.8985
# Multiple hits for don=P3HT and acc=Y1:
# 	 ['P3HT and Y14', 'P3HT and Y1-4F', 'P3HT and Y16', 'P3HT and Y11', 'P3HT and Y15', 'P3HT and Y1']
# Correct: 'P3HT and Y1'
#   Got 'AbsFOM' = 37.458 instead of 35.2405
# Multiple hits for don=PBDB-T and acc=Y1:
# 	 ['PBDB-TF_dimer and Y14', 'PBDB-T_tetra and Y14', 'PBDB-T-2Cl_dimer and Y14', 'PBDB-TF_dimer and Y1-4F', 'PBDB-T_tetra and Y1-4F', 'PBDB-T-2Cl_dimer and Y1-4F', 'PBDB-TF_dimer and Y16', 'PBDB-T_tetra and Y16', 'PBDB-T-2Cl_dimer and Y16', 'PBDB-TF_dimer and Y11', 'PBDB-T_tetra and Y11', 'PBDB-T-2Cl_dimer and Y11', 'PBDB-TF_dimer and Y15', 'PBDB-T_tetra and Y15', 'PBDB-T-2Cl_dimer and Y15', 'PBDB-TF_dimer and Y1', 'PBDB-T_tetra and Y1', 'PBDB-T-2Cl_dimer and Y1']
# Correct: 'PBDB-T_tetra and Y1'
#   Got 'AbsFOM' = 47.6944 instead of 68.6463
# Multiple hits for don=PBDB-T-2Cl and acc=Y1:
# 	 ['PBDB-T-2Cl_dimer and Y14', 'PBDB-T-2Cl_dimer and Y1-4F', 'PBDB-T-2Cl_dimer and Y16', 'PBDB-T-2Cl_dimer and Y11', 'PBDB-T-2Cl_dimer and Y15', 'PBDB-T-2Cl_dimer and Y1']
# Correct: 'PBDB-T-2Cl_dimer and Y1'
#   Got 'AbsFOM' = 45.8402 instead of 43.6227
# Multiple hits for don=PBDB-T and acc=SNBDT1-F:
# 	 ['PBDB-TF_dimer and SNBDT1-F', 'PBDB-T_tetra and SNBDT1-F', 'PBDB-T-2Cl_dimer and SNBDT1-F']
# Correct: 'PBDB-T_tetra and SNBDT1-F'
#   Got 'AbsFOM' = 52.2427 instead of 75.4122
# Multiple hits for don=PBDB-T and acc=IDTCF:
# 	 ['PBDB-TF_dimer and IDTCF', 'PBDB-T_tetra and IDTCF', 'PBDB-T-2Cl_dimer and IDTCF']
# Correct: 'PBDB-T_tetra and IDTCF'
#   Got 'AbsFOM' = 32.3701 instead of 55.5396
# Multiple hits for don=PBDB-T and acc=PC70BM:
# 	 ['PBDB-TF_dimer and PC70BM', 'PBDB-T_tetra and PC70BM', 'PBDB-T-2Cl_dimer and PC70BM']
# Correct: 'PBDB-T_tetra and PC70BM'
#   Got 'AbsFOM' = 23.9657 instead of 47.1353
# Multiple hits for don=PBDB-T and acc=N65-2FIC:
# 	 ['PBDB-TF_dimer and N65-2FIC', 'PBDB-T_tetra and N65-2FIC', 'PBDB-T-2Cl_dimer and N65-2FIC']
# Correct: 'PBDB-T_tetra and N65-2FIC'
#   Got 'AbsFOM' = 45.0039 instead of 68.1735
# Multiple hits for don=PBDB-T and acc=PCBM:
# 	 ['PBDB-TF_dimer and PCBM', 'PBDB-T_tetra and PCBM', 'PBDB-T-2Cl_dimer and PCBM']
# Correct: 'PBDB-T_tetra and PCBM'
#   Got 'AbsFOM' = 20.0733 instead of 43.2429
# Multiple hits for don=PBDB-T and acc=IDIC:
# 	 ['PBDB-TF_dimer and IDIC', 'PBDB-T_tetra and IDIC', 'PBDB-T-2Cl_dimer and IDIC']
# Correct: 'PBDB-T_tetra and IDIC'
#   Got 'AbsFOM' = 35.6539 instead of 58.8234
# Multiple hits for don=PTB7-Th and acc=TPIC:
# 	 ['PTB7-Th_tetra and TPIC-4Cl', 'PTB7-Th_tetra and TPIC', 'PTB7-Th_tetra and TPIC-4F']
# Correct: 'PTB7-Th_tetra and TPIC'
#   Got 'AbsFOM' = 51.6728 instead of 53.9394
# Multiple hits for don=PBDB-TF and acc=TPIC:
# 	 ['PBDB-TF_dimer and TPIC-4Cl', 'PBDB-TF_dimer and TPIC', 'PBDB-TF_dimer and TPIC-4F']
# Correct: 'PBDB-TF_dimer and TPIC'
#   Got 'AbsFOM' = 45.359 instead of 47.6256
# Multiple hits for don=PDCBT-Cl and acc=TPIC:
# 	 ['PDCBT-Cl_tetra and TPIC-4Cl', 'PDCBT-Cl_tetra and TPIC', 'PDCBT-Cl_tetra and TPIC-4F']
# Correct: 'PDCBT-Cl_tetra and TPIC'
#   Got 'AbsFOM' = 42.7807 instead of 45.0473
# Multiple hits for don=P3HT and acc=TPIC:
# 	 ['P3HT and TPIC-4Cl', 'P3HT and TPIC', 'P3HT and TPIC-4F']
# Correct: 'P3HT and TPIC'
#   Got 'AbsFOM' = 35.1227 instead of 37.3893
# Multiple hits for don=PBDB-T and acc=TPIC:
# 	 ['PBDB-TF_dimer and TPIC-4Cl', 'PBDB-T_tetra and TPIC-4Cl', 'PBDB-T-2Cl_dimer and TPIC-4Cl', 'PBDB-TF_dimer and TPIC', 'PBDB-T_tetra and TPIC', 'PBDB-T-2Cl_dimer and TPIC', 'PBDB-TF_dimer and TPIC-4F', 'PBDB-T_tetra and TPIC-4F', 'PBDB-T-2Cl_dimer and TPIC-4F']
# Correct: 'PBDB-T_tetra and TPIC'
#   Got 'AbsFOM' = 45.359 instead of 70.7952
# Multiple hits for don=PBDB-T-2Cl and acc=TPIC:
# 	 ['PBDB-T-2Cl_dimer and TPIC-4Cl', 'PBDB-T-2Cl_dimer and TPIC', 'PBDB-T-2Cl_dimer and TPIC-4F']
# Correct: 'PBDB-T-2Cl_dimer and TPIC'
#   Got 'AbsFOM' = 43.5049 instead of 45.7715
# Multiple hits for don=PBDB-T and acc=F-H:
# 	 ['PBDB-TF_dimer and F-H', 'PBDB-T_tetra and F-H', 'PBDB-T-2Cl_dimer and F-H']
# Correct: 'PBDB-T_tetra and F-H'
#   Got 'AbsFOM' = 44.2836 instead of 67.4532
# Multiple hits for don=PBDB-T and acc=IT-4F:
# 	 ['PBDB-TF_dimer and IT-4F', 'PBDB-T_tetra and IT-4F', 'PBDB-T-2Cl_dimer and IT-4F']
# Correct: 'PBDB-T_tetra and IT-4F'
#   Got 'AbsFOM' = 44.2598 instead of 67.4294
# Multiple hits for don=PBDB-T and acc=Y2:
# 	 ['PBDB-TF_dimer and Y2', 'PBDB-T_tetra and Y2', 'PBDB-T-2Cl_dimer and Y2']
# Correct: 'PBDB-T_tetra and Y2'
#   Got 'AbsFOM' = 42.5139 instead of 65.6834
# Multiple hits for don=PBDB-T and acc=SeTIC4Cl:
# 	 ['PBDB-TF_dimer and SeTIC4Cl', 'PBDB-T_tetra and SeTIC4Cl', 'PBDB-T-2Cl_dimer and SeTIC4Cl']
# Correct: 'PBDB-T_tetra and SeTIC4Cl'
#   Got 'AbsFOM' = 47.5764 instead of 70.7459
# Multiple hits for don=PBDB-T and acc=TPIC-4F:
# 	 ['PBDB-TF_dimer and TPIC-4F', 'PBDB-T_tetra and TPIC-4F', 'PBDB-T-2Cl_dimer and TPIC-4F']
# Correct: 'PBDB-T_tetra and TPIC-4F'
#   Got 'AbsFOM' = 45.5552 instead of 68.7248
# 93 out of 438 were bad!

# %% [markdown]
# Thus, in 93 of 438 cases, the wrong AbsFOM value was taken.
